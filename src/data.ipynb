# %%
import pandas as pd
import os
dir_name="C:/Users/namra/Practicum Dataset/user_data/user01/1598832660/"

# %%
dir = os.listdir( dir_name+'mMag' )
df_list = []

for file in dir:
   df = pd.read_csv(dir_name+"mMag/"+file)
   df['timestamp_s'] = float(os.path.splitext(file)[0])
   df = df.rename(columns={'x': 'mMag_x','y': 'mMag_y','z': 'mMag_z'})
   #df.to_csv(dir_name+"mMag/"+file,index=False)
   df_list.append(df)

df_csv_append = pd.concat(df_list, ignore_index=True)
df_csv_append.to_csv(dir_name+"1598832660_mMag.csv",index=False)

# %%
dir = os.listdir( dir_name+"mAcc" )
df_list = []

for file in dir:
   df = pd.read_csv(dir_name+"mAcc/"+file)
   df['timestamp_s'] = float(os.path.splitext(file)[0])
   df = df.rename(columns={'x': 'mAcc_x','y': 'mAcc_y','z': 'mAcc_z'})
   #df.to_csv(dir_name+"mAcc/"+file,index=False)
   df_list.append(df)

df_csv_append = pd.concat(df_list, ignore_index=True)
df_csv_append
df_csv_append.to_csv(dir_name+"1598832660_mAcc.csv",index=False)

# %%
dir = os.listdir( dir_name+"mGyr" )
df_list = []

for file in dir:
   df = pd.read_csv(dir_name+"mGyr/"+file)
   df['timestamp_s'] = float(os.path.splitext(file)[0])
   df = df.rename(columns={'x': 'mGyr_x','y': 'mGyr_y','z': 'mGyr_z','roll':'mGyr_roll','pitch':'mGyr_pitch', 'yaw':'mGyr_yaw'})
   #df.to_csv(dir_name+"mGyr/"+file,index=False)
   df_list.append(df)

df_csv_append = pd.concat(df_list, ignore_index=True)
df_csv_append.to_csv(dir_name+"1598832660_mGyr.csv",index=False)

# %%
dir = os.listdir( dir_name+"mGps" )
df_list = []

for file in dir:
   df = pd.read_csv(dir_name+"mGps/"+file)
   df['timestamp_s'] = float(os.path.splitext(file)[0])
   df = df.rename(columns={'lat': 'mGps_lat','lon': 'mGps_lon','accuracy': 'mGps_accr'})
   #df.to_csv(dir_name+"mGps/"+file,index=False)
   df_list.append(df)

df_csv_append = pd.concat(df_list, ignore_index=True)
df_csv_append.to_csv(dir_name+"1598832660_mGps.csv",index=False)

# %%
dir = os.listdir( dir_name+"e4Acc" )
df_list = []

for file in dir:
   df = pd.read_csv(dir_name+"e4Acc/"+file)
   df['timestamp_s'] = float(os.path.splitext(file)[0])
   df = df.rename(columns={'x': 'e4Acc_x','y': 'e4Acc_y','z': 'e4Acc_z'})
   #df.to_csv(dir_name+"e4Acc/"+file,index=False)
   df_list.append(df)

df_csv_append = pd.concat(df_list, ignore_index=True)
df_csv_append
df_csv_append.to_csv(dir_name+"1598832660_e4Acc.csv",index=False)

# %%
dir = os.listdir( dir_name+'e4Bvp' )
df_list = []

for file in dir:
   df = pd.read_csv(dir_name+"e4Bvp/"+file)
   df['timestamp_s'] = float(os.path.splitext(file)[0])
   df = df.rename(columns={'value': 'e4Bvp_val'})
   #df.to_csv(dir_name+"e4Bvp/"+file,index=False)
   df_list.append(df)

df_csv_append = pd.concat(df_list, ignore_index=True)
df_csv_append.to_csv(dir_name+"1598832660_e4Bvp.csv",index=False)

# %%
dir = os.listdir( dir_name+'e4Eda' )
df_list = []

for file in dir:
   df = pd.read_csv(dir_name+"e4Eda/"+file)
   df['timestamp_s'] = float(os.path.splitext(file)[0])
   df = df.rename(columns={'eda': 'e4Eda_val'})
   #df.to_csv(dir_name+"e4Eda/"+file,index=False)
   df_list.append(df)

df_csv_append = pd.concat(df_list, ignore_index=True)
df_csv_append.to_csv(dir_name+"1598832660_e4Eda.csv",index=False)

# %%
dir = os.listdir( dir_name+'e4Hr' )
df_list = []

for file in dir:
   df = pd.read_csv(dir_name+"e4Hr/"+file)
   df['timestamp_s'] = float(os.path.splitext(file)[0])
   df = df.rename(columns={'hr': 'e4Hr_val'})
   #df.to_csv(dir_name+"e4Hr/"+file,index=False)
   df_list.append(df)

df_csv_append = pd.concat(df_list, ignore_index=True)
df_csv_append.to_csv(dir_name+"1598832660_e4Hr.csv",index=False)

# %%
dir = os.listdir( dir_name+'e4Temp' )
df_list = []

for file in dir:
   df = pd.read_csv(dir_name+"e4Temp/"+file)
   df['timestamp_s'] = float(os.path.splitext(file)[0])
   df = df.rename(columns={'temp': 'e4Temp_val'})
   #df.to_csv(dir_name+"e4Temp/"+file,index=False)
   df_list.append(df)

df_csv_append = pd.concat(df_list, ignore_index=True)
df_csv_append.to_csv(dir_name+"1598832660_e4Temp.csv",index=False)

# %%
df = pd.read_csv(dir_name+"1598832660_mAcc.csv")
df['timestamp_s']=df['timestamp_s'].astype('int64')
df['timestamp']=df['timestamp']*1000
df['timestamp']=df['timestamp'].astype('int64')
df['timestamp_s']=df['timestamp_s']*1000
df['timestamp']=df['timestamp_s']+df['timestamp']
df.drop(columns=['timestamp_s'],inplace=True)
df.to_csv(dir_name+"1598832660_mAcc.csv",index=False)
df
# Out:
#              timestamp    mAcc_x    mAcc_y    mAcc_z
# 0        1598832660004  0.069434 -0.069434  9.703996
# 1        1598832660016  0.079011 -0.062251  9.701602
# 2        1598832660051  0.079011 -0.081405  9.696813
# 3        1598832660082  0.086194 -0.071828  9.682447
# 4        1598832660121  0.074223 -0.086194  9.718362
# ...                ...       ...       ...       ...
# 1292247  1598879919387  5.399090  0.081405  8.087860
# 1292248  1598879919420  5.399090  0.064645  8.097438
# 1292249  1598879919447  5.389513  0.062251  8.075889
# 1292250  1598879919488  5.389513  0.069434  8.075889
# 1292251  1598879919517  5.394301  0.088588  8.083072
#
# [1292252 rows x 4 columns]

# %%
df = pd.read_csv(dir_name+"1598832660_mMag.csv")
df['timestamp_s']=df['timestamp_s'].astype('int64')
df['timestamp']=df['timestamp']*1000
df['timestamp']=df['timestamp'].astype('int64')
df['timestamp_s']=df['timestamp_s']*1000
df['timestamp']=df['timestamp_s']+df['timestamp']
df.drop(columns=['timestamp_s'],inplace=True)
df.to_csv(dir_name+"1598832660_mMag.csv",index=False)
df
# Out:
#              timestamp     mMag_x  mMag_y     mMag_z
# 0        1598832660015  -11.20000   -15.7 -70.900000
# 1        1598832660061  -11.20000   -15.8 -70.800000
# 2        1598832660091  -11.10000   -15.7 -70.800000
# 3        1598832660131  -11.20000   -15.8 -70.700005
# 4        1598832660152  -11.10000   -15.8 -70.800000
# ...                ...        ...     ...        ...
# 1282842  1598880599860 -163.30000    27.9 -61.200000
# 1282843  1598880599900 -163.30000    28.0 -61.200000
# 1282844  1598880599938 -163.30000    27.9 -61.300000
# 1282845  1598880599958 -163.30000    27.9 -61.300000
# 1282846  1598880599998 -163.40001    28.0 -61.300000
#
# [1282847 rows x 4 columns]

# %%
df = pd.read_csv(dir_name+"1598832660_mGyr.csv")
df['timestamp_s']=df['timestamp_s'].astype('int64')
df['timestamp']=df['timestamp']*1000
df['timestamp']=df['timestamp'].astype('int64')
df['timestamp_s']=df['timestamp_s']*1000
df['timestamp']=df['timestamp_s']+df['timestamp']
df.drop(columns=['timestamp_s'],inplace=True)
df.to_csv(dir_name+"1598832660_mGyr.csv",index=False)
df
# Out:
#              timestamp    mGyr_x    mGyr_y    mGyr_z     mGyr_roll  \
# 0        1598832660018  0.000300  0.000497 -0.000398  7.329460e-09
# 1        1598832660062 -0.002144  0.000497 -0.000398  2.328895e-08
# 2        1598832660091 -0.000922 -0.000114  0.000823 -2.973670e-09
# 3        1598832660132  0.004576 -0.000114  0.001434 -1.149149e-08
# 4        1598832660152  0.000911  0.001718  0.002045  8.136358e-08
# ...                ...       ...       ...       ...           ...
# 1284009  1598880599861  0.000129 -0.000124 -0.001205 -3.800494e-09
# 1284010  1598880599900  0.000740 -0.000124  0.000017 -1.560923e-09
# 1284011  1598880599939  0.001351  0.001098 -0.001205  3.898228e-08
# 1284012  1598880599959 -0.001704  0.000487 -0.001205  1.750112e-08
# 1284013  1598880599999 -0.001704  0.001098  0.000017  3.732700e-08
#
#            mGyr_pitch      mGyr_yaw
# 0       -4.426525e-09  5.877992e-09
# 1        1.005177e-07  1.867699e-08
# 2        2.399609e-08 -2.143587e-08
# ...

# %%
df = pd.read_csv(dir_name+"1598832660_mGps.csv")
df['timestamp_s']=df['timestamp_s'].astype('int64')
df['timestamp']=df['timestamp']*1000
df['timestamp']=df['timestamp'].astype('int64')
df['timestamp_s']=df['timestamp_s']*1000
df['timestamp']=df['timestamp_s']+df['timestamp']
df.drop(columns=['timestamp_s'],inplace=True)
df.to_csv(dir_name+"1598832660_mGps.csv",index=False)
df
# Out:
#            timestamp   mGps_lat    mGps_lon  mGps_accr
# 0      1598832667000  37.482426  126.956290     12.425
# 1      1598832677000  37.482423  126.956288     12.335
# 2      1598832687000  37.482443  126.956309     16.144
# 3      1598832697000  37.482430  126.956295     12.027
# 4      1598832707000  37.482441  126.956304     11.825
# ...              ...        ...         ...        ...
# 11306  1598880585000  37.482462  126.956342     16.157
# 11307  1598880588000  37.482462  126.956317     15.152
# 11308  1598880591000  37.482470  126.956347     14.901
# 11309  1598880594000  37.482482  126.956366     14.901
# 11310  1598880597000  37.482494  126.956373     15.899
#
# [11311 rows x 4 columns]

# %%
df = pd.read_csv(dir_name+"1598832660_e4Acc.csv")
df['timestamp_s']=df['timestamp_s'].astype('int64')
df['timestamp']=df['timestamp']*1000
df['timestamp']=df['timestamp'].astype('int64')
df['timestamp_s']=df['timestamp_s']*1000
df['timestamp']=df['timestamp_s']+df['timestamp']
df.drop(columns=['timestamp_s'],inplace=True)
df.to_csv(dir_name+"1598832660_e4Acc.csv",index=False)
df
# Out:
#             timestamp   e4Acc_x   e4Acc_y   e4Acc_z
# 0       1598833283000 -0.484375 -0.375000 -0.703125
# 1       1598833283031 -0.593750 -0.312500 -0.937500
# 2       1598833283062 -0.890625 -0.609375 -1.140625
# 3       1598833283093 -0.796875 -0.718750 -0.937500
# 4       1598833283125 -0.843750 -0.593750 -0.875000
# ...               ...       ...       ...       ...
# 223351  1598880599843 -0.859375 -0.453125 -0.328125
# 223352  1598880599875 -0.843750 -0.437500 -0.343750
# 223353  1598880599906 -0.828125 -0.453125 -0.375000
# 223354  1598880599937 -0.750000 -0.453125 -0.343750
# 223355  1598880599968 -0.781250 -0.453125 -0.375000
#
# [223356 rows x 4 columns]

# %%
df = pd.read_csv(dir_name+"1598832660_e4Bvp.csv")
df['timestamp_s']=df['timestamp_s'].astype('int64')
df['timestamp']=df['timestamp']*1000
df['timestamp']=df['timestamp'].astype('int64')
df['timestamp_s']=df['timestamp_s']*1000
df['timestamp']=df['timestamp_s']+df['timestamp']
df.drop(columns=['timestamp_s'],inplace=True)
df.to_csv(dir_name+"1598832660_e4Bvp.csv",index=False)
df
# Out:
#             timestamp  e4Bvp_val
# 0       1598833283171       0.01
# 1       1598833283187       0.01
# 2       1598833283218      -0.03
# 3       1598833283234      -0.05
# 4       1598833283250      -0.05
# ...               ...        ...
# 446635  1598880599921     -11.92
# 446636  1598880599937     -10.91
# 446637  1598880599953      -8.90
# 446638  1598880599968      -4.88
# 446639  1598880599984       1.01
#
# [446640 rows x 2 columns]

# %%
df = pd.read_csv(dir_name+"1598832660_e4Eda.csv")
df['timestamp_s']=df['timestamp_s'].astype('int64')
df['timestamp']=df['timestamp']*1000
df['timestamp']=df['timestamp'].astype('int64')
df['timestamp_s']=df['timestamp_s']*1000
df['timestamp']=df['timestamp_s']+df['timestamp']
df.drop(columns=['timestamp_s'],inplace=True)
df.to_csv(dir_name+"1598832660_e4Eda.csv",index=False)
df
# Out:
#            timestamp  e4Eda_val
# 0      1598833283250   0.370126
# 1      1598833283500   0.358600
# 2      1598833283750   0.413671
# 3      1598833284000   0.502040
# 4      1598833284250   0.490514
# ...              ...        ...
# 27905  1598880598750  33.956406
# 27906  1598880599000  33.455372
# 27907  1598880599250  33.519569
# 27908  1598880599500  33.527256
# 27909  1598880599750  32.954777
#
# [27910 rows x 2 columns]

# %%
df = pd.read_csv(dir_name+"1598832660_e4Hr.csv")
df['timestamp_s']=df['timestamp_s'].astype('int64')
df['timestamp']=df['timestamp']*1000
df['timestamp']=df['timestamp'].astype('int64')
df['timestamp_s']=df['timestamp_s']*1000
df['timestamp']=df['timestamp_s']+df['timestamp']
df.drop(columns=['timestamp_s'],inplace=True)
df.to_csv(dir_name+"1598832660_e4Hr.csv",index=False)
df
# Out:
#           timestamp  e4Hr_val
# 0     1598833293000     74.00
# 1     1598833294000     69.00
# 2     1598833295000     74.33
# 3     1598833296000     89.00
# 4     1598833297000     93.80
# ...             ...       ...
# 6956  1598880595000     84.50
# 6957  1598880596000     84.42
# 6958  1598880597000     84.32
# 6959  1598880598000     84.22
# 6960  1598880599000     84.12
#
# [6961 rows x 2 columns]

# %%
df = pd.read_csv(dir_name+"1598832660_e4Temp.csv")
df['timestamp_s']=df['timestamp_s'].astype('int64')
df['timestamp']=df['timestamp']*1000
df['timestamp']=df['timestamp'].astype('int64')
df['timestamp_s']=df['timestamp_s']*1000
df['timestamp']=df['timestamp_s']+df['timestamp']
df.drop(columns=['timestamp_s'],inplace=True)
df.to_csv(dir_name+"1598832660_e4Temp.csv",index=False)
df
# Out:
#            timestamp  e4Temp_val
# 0      1598833283000       33.87
# 1      1598833283250       33.87
# 2      1598833283500       33.87
# 3      1598833283750       33.87
# 4      1598833284000       33.87
# ...              ...         ...
# 27911  1598880598750       33.91
# 27912  1598880599000       33.91
# 27913  1598880599250       33.91
# 27914  1598880599500       33.91
# 27915  1598880599750       33.91
#
# [27916 rows x 2 columns]

# %%
import pandas as pd
import os
mAcc = pd.read_csv(dir_name+"1598832660_mAcc.csv")
mAcc['timestamp']=mAcc['timestamp'].astype('int64')
mMag = pd.read_csv(dir_name+"1598832660_mMag.csv")
mMag['timestamp']=mMag['timestamp'].astype('int64')
combined_csv = pd.merge_asof(mAcc, mMag, on='timestamp',direction='nearest')
combined_csv
# Out:
#              timestamp    mAcc_x    mAcc_y    mAcc_z  mMag_x  mMag_y  \
# 0        1598832660004  0.069434 -0.069434  9.703996   -11.2   -15.7
# 1        1598832660016  0.079011 -0.062251  9.701602   -11.2   -15.7
# 2        1598832660051  0.079011 -0.081405  9.696813   -11.2   -15.8
# 3        1598832660082  0.086194 -0.071828  9.682447   -11.1   -15.7
# 4        1598832660121  0.074223 -0.086194  9.718362   -11.2   -15.8
# ...                ...       ...       ...       ...     ...     ...
# 1292247  1598879919387  5.399090  0.081405  8.087860  -164.5    28.5
# 1292248  1598879919420  5.399090  0.064645  8.097438  -164.5    28.5
# 1292249  1598879919447  5.389513  0.062251  8.075889  -164.5    28.5
# 1292250  1598879919488  5.389513  0.069434  8.075889  -164.5    28.5
# 1292251  1598879919517  5.394301  0.088588  8.083072  -164.5    28.5
#
#             mMag_z
# 0       -70.900000
# 1       -70.900000
# 2       -70.800000
# 3       -70.800000
# 4       -70.700005
# ...

# %%
mGyr = pd.read_csv(dir_name+"1598832660_mGyr.csv")

combined_csv = pd.merge_asof(combined_csv, mGyr, on='timestamp',direction='nearest')
combined_csv
# Out:
#              timestamp    mAcc_x    mAcc_y    mAcc_z  mMag_x  mMag_y  \
# 0        1598832660004  0.069434 -0.069434  9.703996   -11.2   -15.7
# 1        1598832660016  0.079011 -0.062251  9.701602   -11.2   -15.7
# 2        1598832660051  0.079011 -0.081405  9.696813   -11.2   -15.8
# 3        1598832660082  0.086194 -0.071828  9.682447   -11.1   -15.7
# 4        1598832660121  0.074223 -0.086194  9.718362   -11.2   -15.8
# ...                ...       ...       ...       ...     ...     ...
# 1292247  1598879919387  5.399090  0.081405  8.087860  -164.5    28.5
# 1292248  1598879919420  5.399090  0.064645  8.097438  -164.5    28.5
# 1292249  1598879919447  5.389513  0.062251  8.075889  -164.5    28.5
# 1292250  1598879919488  5.389513  0.069434  8.075889  -164.5    28.5
# 1292251  1598879919517  5.394301  0.088588  8.083072  -164.5    28.5
#
#             mMag_z    mGyr_x    mGyr_y    mGyr_z     mGyr_roll    mGyr_pitch  \
# ...

# %%
mGps = pd.read_csv(dir_name+"1598832660_mGps.csv")

combined_csv = pd.merge_asof(combined_csv, mGps, on='timestamp',direction='nearest')
combined_csv
# Out:
#              timestamp    mAcc_x    mAcc_y    mAcc_z  mMag_x  mMag_y  \
# 0        1598832660004  0.069434 -0.069434  9.703996   -11.2   -15.7
# 1        1598832660016  0.079011 -0.062251  9.701602   -11.2   -15.7
# 2        1598832660051  0.079011 -0.081405  9.696813   -11.2   -15.8
# 3        1598832660082  0.086194 -0.071828  9.682447   -11.1   -15.7
# 4        1598832660121  0.074223 -0.086194  9.718362   -11.2   -15.8
# ...                ...       ...       ...       ...     ...     ...
# 1292247  1598879919387  5.399090  0.081405  8.087860  -164.5    28.5
# 1292248  1598879919420  5.399090  0.064645  8.097438  -164.5    28.5
# 1292249  1598879919447  5.389513  0.062251  8.075889  -164.5    28.5
# 1292250  1598879919488  5.389513  0.069434  8.075889  -164.5    28.5
# 1292251  1598879919517  5.394301  0.088588  8.083072  -164.5    28.5
#
#             mMag_z    mGyr_x    mGyr_y    mGyr_z     mGyr_roll    mGyr_pitch  \
# ...

# %%
#combined_csv = pd.read_csv(dir_name+"1598832660_combined.csv")
e4Acc = pd.read_csv(dir_name+"1598832660_e4Acc.csv")

combined_csv = pd.merge_asof(combined_csv, e4Acc, on='timestamp',direction='nearest')
combined_csv
# Out:
#              timestamp    mAcc_x    mAcc_y    mAcc_z  mMag_x  mMag_y  \
# 0        1598832660004  0.069434 -0.069434  9.703996   -11.2   -15.7
# 1        1598832660016  0.079011 -0.062251  9.701602   -11.2   -15.7
# 2        1598832660051  0.079011 -0.081405  9.696813   -11.2   -15.8
# 3        1598832660082  0.086194 -0.071828  9.682447   -11.1   -15.7
# 4        1598832660121  0.074223 -0.086194  9.718362   -11.2   -15.8
# ...                ...       ...       ...       ...     ...     ...
# 1292247  1598879919387  5.399090  0.081405  8.087860  -164.5    28.5
# 1292248  1598879919420  5.399090  0.064645  8.097438  -164.5    28.5
# 1292249  1598879919447  5.389513  0.062251  8.075889  -164.5    28.5
# 1292250  1598879919488  5.389513  0.069434  8.075889  -164.5    28.5
# 1292251  1598879919517  5.394301  0.088588  8.083072  -164.5    28.5
#
#             mMag_z    mGyr_x    mGyr_y    mGyr_z     mGyr_roll    mGyr_pitch  \
# ...

# %%
#combined_csv = pd.read_csv(dir_name+"1598832660_combined.csv")
e4Bvp = pd.read_csv(dir_name+"1598832660_e4Bvp.csv")

combined_csv = pd.merge_asof(combined_csv, e4Bvp, on='timestamp',direction='nearest')
combined_csv
# Out:
#              timestamp    mAcc_x    mAcc_y    mAcc_z  mMag_x  mMag_y  \
# 0        1598832660004  0.069434 -0.069434  9.703996   -11.2   -15.7
# 1        1598832660016  0.079011 -0.062251  9.701602   -11.2   -15.7
# 2        1598832660051  0.079011 -0.081405  9.696813   -11.2   -15.8
# 3        1598832660082  0.086194 -0.071828  9.682447   -11.1   -15.7
# 4        1598832660121  0.074223 -0.086194  9.718362   -11.2   -15.8
# ...                ...       ...       ...       ...     ...     ...
# 1292247  1598879919387  5.399090  0.081405  8.087860  -164.5    28.5
# 1292248  1598879919420  5.399090  0.064645  8.097438  -164.5    28.5
# 1292249  1598879919447  5.389513  0.062251  8.075889  -164.5    28.5
# 1292250  1598879919488  5.389513  0.069434  8.075889  -164.5    28.5
# 1292251  1598879919517  5.394301  0.088588  8.083072  -164.5    28.5
#
#             mMag_z    mGyr_x    mGyr_y    mGyr_z     mGyr_roll    mGyr_pitch  \
# ...

# %%
#combined_csv = pd.read_csv(dir_name+"1598832660_combined.csv")
e4Temp = pd.read_csv(dir_name+"1598832660_e4Temp.csv")

combined_csv = pd.merge_asof(combined_csv, e4Temp, on='timestamp',direction='nearest')
combined_csv
# Out:
#              timestamp    mAcc_x    mAcc_y    mAcc_z  mMag_x  mMag_y  \
# 0        1598832660004  0.069434 -0.069434  9.703996   -11.2   -15.7
# 1        1598832660016  0.079011 -0.062251  9.701602   -11.2   -15.7
# 2        1598832660051  0.079011 -0.081405  9.696813   -11.2   -15.8
# 3        1598832660082  0.086194 -0.071828  9.682447   -11.1   -15.7
# 4        1598832660121  0.074223 -0.086194  9.718362   -11.2   -15.8
# ...                ...       ...       ...       ...     ...     ...
# 1292247  1598879919387  5.399090  0.081405  8.087860  -164.5    28.5
# 1292248  1598879919420  5.399090  0.064645  8.097438  -164.5    28.5
# 1292249  1598879919447  5.389513  0.062251  8.075889  -164.5    28.5
# 1292250  1598879919488  5.389513  0.069434  8.075889  -164.5    28.5
# 1292251  1598879919517  5.394301  0.088588  8.083072  -164.5    28.5
#
#             mMag_z    mGyr_x    mGyr_y    mGyr_z  ...    mGyr_pitch  \
# 0       -70.900000  0.000300  0.000497 -0.000398  ... -4.426525e-09
# ...

# %%
#combined_csv = pd.read_csv(dir_name+"1598832660_combined.csv")
e4Hr = pd.read_csv(dir_name+"1598832660_e4Hr.csv")

combined_csv = pd.merge_asof(combined_csv, e4Hr, on='timestamp',direction='nearest')
combined_csv
# Out:
#              timestamp    mAcc_x    mAcc_y    mAcc_z  mMag_x  mMag_y  \
# 0        1598832660004  0.069434 -0.069434  9.703996   -11.2   -15.7
# 1        1598832660016  0.079011 -0.062251  9.701602   -11.2   -15.7
# 2        1598832660051  0.079011 -0.081405  9.696813   -11.2   -15.8
# 3        1598832660082  0.086194 -0.071828  9.682447   -11.1   -15.7
# 4        1598832660121  0.074223 -0.086194  9.718362   -11.2   -15.8
# ...                ...       ...       ...       ...     ...     ...
# 1292247  1598879919387  5.399090  0.081405  8.087860  -164.5    28.5
# 1292248  1598879919420  5.399090  0.064645  8.097438  -164.5    28.5
# 1292249  1598879919447  5.389513  0.062251  8.075889  -164.5    28.5
# 1292250  1598879919488  5.389513  0.069434  8.075889  -164.5    28.5
# 1292251  1598879919517  5.394301  0.088588  8.083072  -164.5    28.5
#
#             mMag_z    mGyr_x    mGyr_y    mGyr_z  ...      mGyr_yaw  \
# 0       -70.900000  0.000300  0.000497 -0.000398  ...  5.877992e-09
# ...

# %%
#combined_csv = pd.read_csv(dir_name+"1598832660_combined.csv")
e4Eda = pd.read_csv(dir_name+"1598832660_e4Eda.csv")

combined_csv = pd.merge_asof(combined_csv, e4Eda, on='timestamp',direction='nearest')
combined_csv
# Out:
#              timestamp    mAcc_x    mAcc_y    mAcc_z  mMag_x  mMag_y  \
# 0        1598832660004  0.069434 -0.069434  9.703996   -11.2   -15.7
# 1        1598832660016  0.079011 -0.062251  9.701602   -11.2   -15.7
# 2        1598832660051  0.079011 -0.081405  9.696813   -11.2   -15.8
# 3        1598832660082  0.086194 -0.071828  9.682447   -11.1   -15.7
# 4        1598832660121  0.074223 -0.086194  9.718362   -11.2   -15.8
# ...                ...       ...       ...       ...     ...     ...
# 1292247  1598879919387  5.399090  0.081405  8.087860  -164.5    28.5
# 1292248  1598879919420  5.399090  0.064645  8.097438  -164.5    28.5
# 1292249  1598879919447  5.389513  0.062251  8.075889  -164.5    28.5
# 1292250  1598879919488  5.389513  0.069434  8.075889  -164.5    28.5
# 1292251  1598879919517  5.394301  0.088588  8.083072  -164.5    28.5
#
#             mMag_z    mGyr_x    mGyr_y    mGyr_z  ...   mGps_lat    mGps_lon  \
# ...

# %%
labels = pd.read_csv(dir_name+"1598832660_label.csv")
labels.rename(columns={'ts':'timestamp'},inplace='True')
labels['timestamp']=labels['timestamp'].astype('int64')
labels['timestamp']=labels['timestamp']*1000
labels
# Out:
#          timestamp     action  actionOption actionSub  actionSubOption  \
# 0    1598832660000  household            43       NaN              NaN
# 1    1598832720000  household            43       NaN              NaN
# 2    1598832780000  household            43       NaN              NaN
# 3    1598832840000  household            43       NaN              NaN
# 4    1598832900000  household            43       NaN              NaN
# ..             ...        ...           ...       ...              ...
# 774  1598880300000      study           313       NaN              NaN
# 775  1598880360000      study           313       NaN              NaN
# 776  1598880420000      study           313       NaN              NaN
# 777  1598880480000      study           313       NaN              NaN
# 778  1598880540000      study           313       NaN              NaN
#
#     condition  conditionSub1Option  conditionSub2Option place  \
# ...

# %%
combined_csv = pd.merge_asof(combined_csv, labels, on='timestamp',direction='nearest')
combined_csv
# Out:
#              timestamp    mAcc_x    mAcc_y    mAcc_z  mMag_x  mMag_y  \
# 0        1598832660004  0.069434 -0.069434  9.703996   -11.2   -15.7
# 1        1598832660016  0.079011 -0.062251  9.701602   -11.2   -15.7
# 2        1598832660051  0.079011 -0.081405  9.696813   -11.2   -15.8
# 3        1598832660082  0.086194 -0.071828  9.682447   -11.1   -15.7
# 4        1598832660121  0.074223 -0.086194  9.718362   -11.2   -15.8
# ...                ...       ...       ...       ...     ...     ...
# 1292247  1598879919387  5.399090  0.081405  8.087860  -164.5    28.5
# 1292248  1598879919420  5.399090  0.064645  8.097438  -164.5    28.5
# 1292249  1598879919447  5.389513  0.062251  8.075889  -164.5    28.5
# 1292250  1598879919488  5.389513  0.069434  8.075889  -164.5    28.5
# 1292251  1598879919517  5.394301  0.088588  8.083072  -164.5    28.5
#
#             mMag_z    mGyr_x    mGyr_y    mGyr_z  ...  actionOption  \
# 0       -70.900000  0.000300  0.000497 -0.000398  ...            43
# ...

# %%
combined_csv.columns
# Out:
# Index(['timestamp', 'mAcc_x', 'mAcc_y', 'mAcc_z', 'mMag_x', 'mMag_y', 'mMag_z',
#        'mGyr_x', 'mGyr_y', 'mGyr_z', 'mGyr_roll', 'mGyr_pitch', 'mGyr_yaw',
#        'mGps_lat', 'mGps_lon', 'mGps_accr', 'e4Acc_x', 'e4Acc_y', 'e4Acc_z',
#        'e4Bvp_val', 'e4Temp_val', 'e4Hr_val', 'e4Eda_val', 'action',
#        'actionOption', 'actionSub', 'actionSubOption', 'condition',
#        'conditionSub1Option', 'conditionSub2Option', 'place',
#        'emotionPositive', 'emotionTension', 'activity'],
#       dtype='object')

# %%
combined_csv.drop(columns=['actionOption','actionSub', 'actionSubOption', 'condition', 'conditionSub1Option',
      'conditionSub2Option','place','emotionPositive', 'emotionTension','activity','mGps_accr'], inplace=True)
combined_csv = combined_csv.iloc[::32, :]      
combined_csv['date_time'] = pd.to_datetime(combined_csv['timestamp'], unit='ms').dt.tz_localize('UTC').dt.tz_convert('Asia/Seoul').dt.tz_localize(None)
combined_csv.to_csv(dir_name+"1598832660_combined.csv",index=False)
combined_csv
# Out:
#              timestamp    mAcc_x    mAcc_y    mAcc_z  mMag_x  mMag_y  \
# 0        1598832660004  0.069434 -0.069434  9.703996   -11.2   -15.7
# 1        1598832660016  0.079011 -0.062251  9.701602   -11.2   -15.7
# 2        1598832660051  0.079011 -0.081405  9.696813   -11.2   -15.8
# 3        1598832660082  0.086194 -0.071828  9.682447   -11.1   -15.7
# 4        1598832660121  0.074223 -0.086194  9.718362   -11.2   -15.8
# ...                ...       ...       ...       ...     ...     ...
# 1292247  1598879919387  5.399090  0.081405  8.087860  -164.5    28.5
# 1292248  1598879919420  5.399090  0.064645  8.097438  -164.5    28.5
# 1292249  1598879919447  5.389513  0.062251  8.075889  -164.5    28.5
# 1292250  1598879919488  5.389513  0.069434  8.075889  -164.5    28.5
# 1292251  1598879919517  5.394301  0.088588  8.083072  -164.5    28.5
#
#             mMag_z    mGyr_x    mGyr_y    mGyr_z  ...    mGps_lon   e4Acc_x  \
# ...

# %%
combined_csv.action.unique()
# Out:
# array(['household', 'travel', 'personal_care', 'meal', 'recreation_media',
#        'work', 'study'], dtype=object)

# %%
combined_csv.isna().sum()
# Out:
# timestamp     0
# mAcc_x        0
# mAcc_y        0
# mAcc_z        0
# mMag_x        0
# mMag_y        0
# mMag_z        0
# mGyr_x        0
# mGyr_y        0
# mGyr_z        0
# mGyr_roll     0
# mGyr_pitch    0
# mGyr_yaw      0
# mGps_lat      0
# mGps_lon      0
# e4Acc_x       0
# e4Acc_y       0
# e4Acc_z       0
# e4Bvp_val     0
# e4Temp_val    0
# e4Hr_val      0
# e4Eda_val     0
# action        0
# date_time     0
# dtype: int64

# %%
combined_csv.dtypes
# Out:
# timestamp                          int64
# mAcc_x                           float64
# mAcc_y                           float64
# mAcc_z                           float64
# mMag_x                           float64
# mMag_y                           float64
# mMag_z                           float64
# mGyr_x                           float64
# mGyr_y                           float64
# mGyr_z                           float64
# mGyr_roll                        float64
# mGyr_pitch                       float64
# mGyr_yaw                         float64
# mGps_lat                         float64
# mGps_lon                         float64
# e4Acc_x                          float64
# e4Acc_y                          float64
# e4Acc_z                          float64
# e4Bvp_val                        float64
# e4Temp_val                       float64
# e4Hr_val                         float64
# e4Eda_val                        float64
# action                            object
# ...
